# %% [markdown]
# # COMMODITY
#
#    Commodities are all the goods and products which tradeable.They consist of a large group of products like precious metals, industrial metals, energy resources, agricultural products, foodstuffs, raw materials, chemicals, forestry products.The values of commodities are determined by consumers.This means that we can talk about supply and demand.The commodities indicate the material resources and richness of the country to which the commodities belong.The petroleum commodities which have strategic consideration is the best example in this regard.
#
# # COMMODITY MARKET
#
#    The products and goods which explained above are traded on the commodity market.Gold, silver, petroleum, wheat, natural gas, cocoa, corn, cotton are the most invested commodities.It can be traded on time and on demand.Commodities are the most reliable investments according to others. The reason is that investors can easily think about their future prices as they are used in daily life.Commodities become investors' favorite investment areas during periods of crisis, chaos and war.
#
# ### WORLD COMMODITY MARKET
#
#    The purchase and sale of commodities were initially made directly face-to-face.
# But increased product diversity, supply and demand and the parties' willingness of non-physical trading transactions then commodity investments have moved to the stock exchange.There is a large range of products in these stock markets ,which are commodity markets, and products are traded as sub-market transactions of some financial stock exchanges, while products such as energy and gold also have their own specialized stock exchanges.There are also contracts based commodities other than commodities that can be bought and sold instantly on spot markets. In the spot markets, while the physical buying and selling transactions were mainly concerned, the maturity parameters were added to the contracts in the derivative products market and non-physical buying and selling transactions occurred. Commodity exchanges concentrated on particular products.
#
# _Before we concentrate in how commodity market works we should know some specific terms about market that we will also need during the study._
#
# #### FUTURES COMMODITY MARKET
#
#    In this market negotiations are made today, but the obligations will be fulfilled on a certain date set in the future.
#
# #### FUTURES COMMODITY CONTRACT
#
#    They are commodity contracts that require delivery at a certain time in the future.
#
# #### CONTINUOUS FUTURES CONTRACT
#
#    The continuous futures contract consists of several futures contracts brought together to form a long-term chart.The time between these contracts will result in gaps in the chart.Constant data arrangements are made to remove these gaps and create a uniform price range.
#
# #### SPOT MARKET
#
#    It is also said cash market. It is used for the short term payment and delivery.
#
#
# ### HOW COMMODITY MARKET WORKS
#
#    The commodity exchange operates according to the exchange rules. So, the logic is: Invest when price is low, sell when price rises. And it need to be known about the physical properties and the factors which affect these physical properties of the commodity to be invested.It is used basic analysis methods to find them but it also should be examined global effects.
# All the situations in the world have an impact on the participants of the market and prices fluctuate.
#    In addition to basic analyzes, technical analyzes are also required. Most of technical analyzes in the stock market work on points that may arise in the future by looking at the past situation of prices.Technical analysis methods act with the belief that everything that happened in the past can be experienced in the future and make a situation assessment through certain graphs, indicators and formations.
#    So,when basic and technical analysis methods are used together, estimates can be made on the future formation of commodities.
#
#
# _In this study, we will try to identify the fluctuations on our commodity data using the analysis methods we have mentioned, and try to explain the reasons for expected or unexpected fluctuations.
# With these analysis, we aim to be able to forecast the future occurrences of the commodity data we work in._
#
# ### DATA INFORMATION OF THESIS
#
#    We are using Quandl as data source in thesis that Quandl delivers market data from hundreds of sources via API, or directly into Python, R, Excel and many other tools. It can be checked our data sets and many other commodities data set by the link below:
#
# https://www.quandl.com/collections/markets/commodities.
#
#    We have two different commodity data sets for this thesis.The features of these data sets and related links are shared below. These datasets belong to Core Financial Data in Quandl.
# We will use the R programming language to apply the above-mentioned methods on the data we receive from Quandl.
#
#
# 1-	https://www.quandl.com/data/ODA/PBANSOP_USD-Bananas-Price
#
# 2- https://www.quandl.com/data/LBMA/GOLD-Gold-Price-London-Fixing
#
# ##### Banana Price
#    Consist of 2 columns which are "Date" and "Value" and 450 rows.
#
# **Description:**Bananas, Central American and Ecuador, FOB U.S. Ports, US$ per metric ton.
#
# **Units:**US Dollars per Metric Ton.
#
# **Alternative source to Quandl:**This data is sourced from www.opendataforafrica.org/IMFPCP2014Jan where it is offered under an open data licence (www.opendataforafrica.org/legal/termsofuse).
#
# ##### Gold Price
# Consist of 6 columns which are "Date" , "USD(AM)", "USD(PM)", "GBP(AM)", "GBP(PM)", "EUR(AM)" and "EUR(PM)" and 600 rows.
#
# **Description:** London Fixings, London Bullion Market Association (LBMA). Fixing levels are set per troy ounce. The London Gold Fixing Companies set the prices for gold that are globally considered as the international standard for pricing of gold. The Gold price in London is set twice a day by five LBMA Market Makers who comprise the London Gold Market Fixing Limited (LGMFL). The process starts with the announcement from the Chairman of the LGMFL to the other members of the LBMA Market Makers, then relayed to the dealing rooms where customers can express their interest as buyers or sellers and also the quantity they wish to trade. The gold fixing price is then set by collating bids and offers until the supply and demand are matched. At this point the price is announced as the 'Fixed' price for gold and all business is conducted on the basis of that price.
#
#
# #### BANANA MARKET
#
# Bananas are one of the oldest fattening plants and the banana plantation dates back to BC There is evidence that it began in 8000 or earlier.
# 	Bananas are unique to South and Southeast Asia, but are among the most consumed in the world and are most commonly consumed in the United States.
# 	During dearth season, bananas are a valuable food source in many countries.
# 	This is particularly important in countries that do not receive the majority of food resources and is also crucial in the global food safety of the banana.
# 	Banana is grown in limited areas in the world, produced by developing countries, and has a very wide market area.
# 	India is the top of the world for banana production.
# 	When we look at the world banana tradition, it is seen that developed countries are importers.
# 	The countries of Europe, Japan and USA are the biggest importer countries.
# 	The share of these countries in the import of world banana is around 65 percent.
# 	North American countries; the customs untaxed and without quota, the Central and South American countries, the European Union countries; Spain and African countries, Japan; It imports bananas from the Philippines and Ecuador.
# 	The world keeps bananas exports in a certain number of developing countries. Only South America and the Caribbean countries account for 84 per cent of global export.
# 	Ecuador, Costa Rica, the Philippines and Colombia. Ecuador alone supplies 25 of the exports of corn bananas alone. As a matter of fact, Ecuador and Costa Rica countries account for 17 percent and 23 percent of their total exports, respectively.
# 	On the other hand, countries such as Belgium and France, whose production is very low, re-export the banana they imported.
# 	Bananas that can not go out of certain areas of production in the world; it is a product demanded because it is delicious, exotic and nutritious.
# 	However, this limited production can not meet the demand, so the price is rising.
#
#
#
# #### GOLD MARKET
#
# The gold stocks are corporate markets with a great emphasis on gold history.
# 	In terms of gold's handling of the international arena and the prevention of problems in imports, the gold stock exchange has an important relative.
# 	While investing in gold provides better opportunities than goldsmiths and banks, a stock exchange feature causes the forex market to remain backward.
# 	Gold stocks are the markets where gold buyers and sellers come together, where gold is traded in physical or non-physical forms.
# 	Due to the high trading volume of gold, the gold stocks have been established as a result of leaving the stock market.
# 	Gold futures can be hedged for risk protection, arbitrage and speculation.
# 	Non-physical trading is also an advantage of the gold exchange.
# 	As in the Forex market, non-physical trading facilitates investment transactions.
# 	At the same time, the events of theft that we hear almost every day will be prevented in this way.
# 	Gold investment is made with gold certificates, gold joint investment funds, stocks of gold mine companies and gold futures.

# %%
library(Quandl)
# Out:
# Loading required package: xts
# Loading required package: zoo
#
# Attaching package: 'zoo'
#
# The following objects are masked from 'package:base':
#
#     as.Date, as.Date.numeric

# %%
banana<- Quandl("ODA/PBANSOP_USD", api_key="2Tn6xx-X8y8ywzbtYPWZ")
gold<- Quandl("LBMA/GOLD", api_key="2Tn6xx-X8y8ywzbtYPWZ", collapse="monthly")

# %%
head(banana)
summary(banana)
# Out:
#   Date       Value
# 1 2017-06-30 1098.07
# 2 2017-05-31 1083.05
# 3 2017-04-30 1063.54
# 4 2017-03-31 1075.25
# 5 2017-02-28 1040.10
# 6 2017-01-31  974.03
#       Date                Value
#  Min.   :1980-01-31   Min.   : 250.5
#  1st Qu.:1989-06-07   1st Qu.: 407.5
#  Median :1998-10-15   Median : 511.4
#  Mean   :1998-10-15   Mean   : 590.4
#  3rd Qu.:2008-02-21   3rd Qu.: 805.2
#  Max.   :2017-06-30   Max.   :1151.4

# %%
head(gold)
summary(gold)
# Out:
#   Date       USD (AM) USD (PM) GBP (AM) GBP (PM) EURO (AM) EURO (PM)
# 1 2017-12-31 1265.85  1264.55   945.97   947.15  1065.09   1065.64
# 2 2017-11-30 1282.15  1280.20   952.64   948.88  1084.06   1074.98
# 3 2017-10-31 1274.40  1270.15   964.21   959.09  1095.60   1091.69
# 4 2017-09-30 1286.95  1283.10   963.15   960.02  1090.82   1087.43
# 5 2017-08-31 1305.80  1311.75  1013.17  1019.62  1098.31   1106.85
# 6 2017-07-31 1266.35  1267.55   965.59   965.49  1079.06   1078.56
#       Date               USD (AM)          USD (PM)          GBP (AM)
#  Min.   :1968-01-31   Min.   :  34.98   Min.   :  34.99   Min.   :  14.54
#  1st Qu.:1980-07-23   1st Qu.: 272.55   1st Qu.: 273.65   1st Qu.: 173.53
#  Median :1993-01-15   Median : 376.12   Median : 376.45   Median : 227.82
#  Mean   :1993-01-14   Mean   : 503.25   Mean   : 505.37   Mean   : 310.61
#  3rd Qu.:2005-07-07   3rd Qu.: 585.38   3rd Qu.: 589.75   3rd Qu.: 286.43
# ...

# %% [markdown]
# _In this study we use only USD AM column of gold data._

# %% [markdown]
# # TIME SERIES
#
# _Definition:_ Time series are a series of measurements of variables collected over time. Often, measurements are made at regular intervals.
#
#
# The purpose of analysis of the time series is to identify the understanding of the truth and the correct value of the future values of the variables in the time series to be forecast.
# Time series data can have a wide variety of models and it is useful to categorize some of the models and behaviors that can be seen in the time series.For this reason, a method has been developed to separate time series into a **_trend_**, a **_seasonal_**, **_a cyclical_** and an **_irregular component_**.
#
# Once the time series is divided into all these components, they can be expressed as the sum or product of these components.
#
#
# ### Time Series Components
#
# ##### Trend
#
# There is a trend when there is a prolonged increase or decrease in the data. It does not have to be linear.
# Sometimes an increasing tendency may pass down a decreasing tendency.
#
# ##### Seasonal
#
# Time series refers to changing according to seasons.Some periods of data used in terms of different from other periods and then seasonal pattern is formed.Seasonal is always a fixed and known period.
#
# ##### Cyclical
#
# Periodic changes that are not related to seasonal changes. For example, the cyclic process describes short-term expansion or contraction in the economy, independent of the general trend.These fluctuations usually long at least 2 years.
#
# ##### Irregular Component
#
# The irregular component is stochastic and our aim is to make a forecast using this component.
#
# ![Time-Series-Analysis-Decomposition.jpg](Time-Series-Analysis-Decomposition.jpg)

# %% [markdown]
# _The followings are the time series plot for our data sets:_

# %%
bananatimeseries<-Quandl("ODA/PBANSOP_USD", api_key="2Tn6xx-X8y8ywzbtYPWZ", type="ts")
plot.ts(bananatimeseries)
# Out:
# plot without title

# %%
goldtimeseries<-Quandl(c("LBMA/GOLD.1"), api_key="2Tn6xx-X8y8ywzbtYPWZ", collapse="monthly" , type="ts")
plot.ts(goldtimeseries)
# Out:
# plot without title

# %% [markdown]
# In the above data sets, a cyclic pattern seems to be non-existent. So we will build our model based on the following function:
#
# $$Y_t= f(Trend_t , Seasonality_t , Remainder_t)$$

# %% [markdown]
# # Time Series Decomposition
#
# _**Additive Model**: A data model in which the effects of individual factors are differentiated and added together to model the data. An additive model is optional for decomposition procedures._
#
# We consider that the $Y_t$ time series consists of three components: a seasonal component, a component of a trend loop, and the remaining component. We can express this model in the following way,
#
# $$ y_t = S_t + T_t + E_t $$
#
#
# _**Multiplicative Model**: This model assumes that as the data increase, so does the seasonal pattern. Most time series plots exhibit such a pattern. In this model, the trend and seasonal components are multiplied and then added to the error component._
#
# Where $y_t$ is the t-period value, $S_t$ is the seasonal component at time t, $T_t$ is the component of the trend cycle at time t, and $E_t$ is the remaining component at time t. Alternatively, a multiplicative model is written as follows:
#
# $$ y_t = S_t \times T_t \times E_t$$
#
#
#
# If the size of the seasonal fluctuations or the variation around the trend cycle does not depend on the level of the time series, the additive model is most appropriate. A multiplicative model is more suitable if the variation around the seasonal pattern or the variation around the trend line is proportional to the level of the time series. Multiplicative models have become widespread with economic time series.
#
# An alternative way of using a multiplicative model is to transform the data first as far as the variant in the heave is stable over time, and then use an additive model. When using a day conversion, it is equivalent to using a multiplicative decay
# $y_t = S_t \times T_t \times E_t$, equivalent to $logy_t = logS_t + logT_t + logE_t$.

# %%
bananatscomp_add<- decompose(bananatimeseries,type=c("additive"))
plot(bananatscomp_add)
# Out:
# plot without title

# %%
bananatscomp_mult<- decompose(bananatimeseries,type=c("multiplicative"))
plot(bananatscomp_mult)
# Out:
# plot without title

# %%
goldtscomp_add<-decompose(goldtimeseries, type=c("additive"))
plot(goldtscomp_add)
# Out:
# plot without title

# %%
goldtscomp_mult<-decompose(goldtimeseries, type=c("multiplicative"))
plot(goldtscomp_mult)
# Out:
# plot without title

# %% [markdown]
# # STL Decomposition
#
# STL, "Seasonal and Trend Decomposition using Loess" is a method used to estimate nonlinear relationships. It decomposes a time series into seasonal, trend and irregular components using loess. The methodology was presented by Robert Cleveland, William Cleveland, Jean McRae and Irma Terpenning in the Journal of Official Statistics in 1990.
#
# STL has some advantages over the classical decomposition method:
#
# 1. STL does not only have a certain frequency, it works for every kind of seasonality.
# 2. The seasonal component is allowed to change over time and the rate of change can be controlled by the user.
# 3. The smoothness of the power cycle can also be controlled by the user.
#
# Because of that STL decomposition works with only additive time series, we should take logs of gold data to obtain a multiplicative decomposition of it.
#
# ##### Loess
# Loess ("locally-weighted scatterplot smoothing") uses local regression to remove "jaggedness" from data.
# A window of a certain width is placed over the data. The wider the window, the smoother the resulting loess curve becomes.
# A regression line (or curve) is placed in the observations falling into the window; the points closest to the center of the window are weighted to have the greatest effect on the calculation of the regression line.
# The weighting is reduced on the farthest points from the window's regression line. The regression is restarted and the weights are recalculated. This process is repeated several times.
# So, we get a point on the loess curve. This is the point on the regression line in the middle of the window.
# Loess is calculated by moving the curve over the window's data. Each point on the resulting root curve is the intersection of a regression line and a vertical line in the middle of such a window.

# %%
plot(stl(bananatimeseries,s.window="periodic"))
# Out:
# plot without title

# %%
loggoldtimeseries<-log10(goldtimeseries)
plot(stl(loggoldtimeseries, s.window="periodic"))
# Out:
# plot without title

# %%
allow.multiplicative.trend=TRUE
stlgold <-stl(goldtimeseries,"periodic")
plot(stlgold)
# Out:
# plot without title

# %% [markdown]
# As we observed from the above plots that the functions stl() and decompose() give the same results. In this case, we will continue to work with the decompose() function.

# %% [markdown]
# _We are using "na.omit" code to delete NA data points of our data sets that may cause problems during the process._

# %%
summary(bananatscomp_add$random)
residualbanana_add<-na.omit(bananatscomp_add$random)
plot.ts(residualbanana_add)
# Out:
#      Min.   1st Qu.    Median      Mean   3rd Qu.      Max.      NA's
# -188.6794  -45.3058   -4.9202    0.1984   36.7826  245.5661        12
# plot without title

# %%
summary(bananatscomp_mult$random)
residualbanana_mult<-na.omit(bananatscomp_mult$random)
plot.ts(residualbanana_mult)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#  0.5740  0.9052  0.9880  0.9997  1.0779  1.4400      12
# plot without title

# %%
summary(goldtscomp_add$random)
residualgold_add<-na.omit(goldtscomp_add$random)
plot.ts(residualgold_add)
# Out:
#       Min.    1st Qu.     Median       Mean    3rd Qu.       Max.       NA's
# -207.72682  -10.65521   -0.83481   -0.07796    9.50350  208.32728         12
# plot without title

# %%
summary(goldtscomp_mult$random)
residualgold_mult<-na.omit(goldtscomp_mult$random)
plot.ts(residualgold_mult)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#  0.7888  0.9691  0.9979  0.9978  1.0248  1.3199      12
# plot without title

# %% [markdown]
# # ARIMA MODELS
#
# The main idea of ARIMA models is that the final residual should seem as white noise, if does not, this means there is still information in the data to extract.Before we introduce ARIMA models, we need to first discuss the concept of stationarity.
#
# #### Stationarity
#
# The stationary means that statistical structure of the series is independent of time.ARIMA models can only be applied to a fixed data series or a series converted to a stationary.Stationarity matters because it provides a framework in which averaging (used in AR and MA processes) can be properly used to describe the time series behaviour.We we explain how to make stationary the data in the first part of ARIMA.
#
#
# ARIMA has three parts: AR(AutoRegressive), I(Integrated) and MA(Moving Average). Notation of ARIMA modeil is ARIMA(p,d,q). p,d and q are the levels for each part mentioned above. Aim of each three step is to provide residuals display a white noise pattern or no pattern at all.
#
# Steps of ARIMA analysis is as following:
#
# #### **I(Integrated)**:
# We can extract trend from original data in this part. Differencing, which is estimating the differences between consecutive observations, is the most common way to do that.
#
# ![differencing.PNG](attachment:differencing.PNG)
#
# Most of time series become trendless after 1st difference that is represented as ARIMA(0,1,0).
#
# #### **AR(AutoRegressive)**:
# We can extract the influence of previous periods' effects.
#
# AR model of order p can be written as;
#
# ![AR.PNG](AR.PNG)
#
# In this equation, c is a constant and $e_t$ is white noise. This is a regression model with the time lagged period values as predictors and is referred as an **AR(p)** model.
#
# #### **MA(Moving Average)**:
# We can extract the influence of the previous period’s error terms on the current period’s error.
#
# ![MA.PNG](MA.PNG)
#
# c is a constant and $e_t$ is white noise. This is a simple multilinear regression model with the time lagged period values as predictors and is referred as an **MA(q)** model.
#
# ## ARIMA Modeling in R
#
# ### Auto.arima()
#
# To implement ARIMA in the R programming language, we use the auto.arima() function. Auto.arima() works by shrinking the AICc and MLE to get an ARIMA model and using a variant of the Hyndman & Khandakar algorithm. Let's explain the AIC and MLE before we examine the steps of the auto.arima().
#
# ###### Akaike's Information Criterion (AIC)
#
# AIC compares the quality of statistical models with each other. An example is which variables contribute to low socioeconomic status and how these variables contribute to this situation. The AIC takes every model and orders it from the best to the worst. The "best" model will neither be incompatible nor overly compliant.
# Since AIC does not provide absolute goodness, after selecting the best model, a hypothesis test is established to measure the distinction between model variables and outcomes.
#
# AICc is defined as follows: $$ AICc = -2LogLikelihood + 2k + 2k(k+1) / (n-k-1) $$
#
# where k is the number of estimated parameters in the model and n is the number of observations in the data set. This value can be used to compare various models for the same data set to determine the best-fitting model.
#
# ###### Maximum Likelihood Estimation (MLE)
#
# Maximum Likelihood is a way to find the most likely function to explain a set of observed data.MLE takes known probability distributions (like the normal distribution) and compares data sets to those distributions in order to find a suitable match for the data. A Family of distributions can have an infinite amount of possible parameters. Maximum Likelihood Estimation is one way to find the parameters of the population that is most likely to have generated the sample being tested.MLE chooses the model parameters based on the values that maximize the Likelihood Function.
#
#
# Auto.arima () is used to automatically generate an optimal array (p, d, q). This function scans parameter combinations and selects the set that best fits the model compliance criteria.
#
# The Akaike Information Criterion (AIC) and the Bayesian Information Criterion (BIC) are used most often to compare the quality of harmony in multiple models.
#
# Auto.arima () allows the user to set the maximum level for (p, d, q) by default and is set to 5 by default. It is very useful for the user.
#
#
# ## Autocorrelation Function and Partial Autocorrelation Function Plots
#
# We are able to identify the number of AR and MA terms that we will need later by looking at the (ACF) and (PACF) plots of the differing series.
#
#
# ### ACF
#
# A correlogram also called Auto Correlation Function Plot or Autocorrelation plot is a visual way of showing the series correlation of time series data.Autocorrelation is the point where a fault at a point advances to the next point.It is the linear correlation of a signal with itself at two different points in time, ACF is just such correlation as a function of the lag h  between two points of time, like acf(h)=corr($ x_t $ ,$ x_{t+h} $). The ACF for a time series $y_t$ , _t = 1,...,N_, is the sequence $ρ_h$ , _h = 1, 2,...,N – 1_.
#
# Autocorrelation plots are a visual tool for determining whether a series is stationary. These plots also help to select the parameters of the ARIMA model.ACF drawings show the relationship between a sequence and delays. Besides suggesting the order of the differences, ACF drawings can help in determining the order of the MA(q) model.
#
# ### PACF
#
# Partial autocorrelation function is essentially the autocorrelation of a signal with itself at different points in time, with linear dependency with that signal at shorter lags removed, as a function of lag between points of time. The partial correlation between $x_t$ and $x_t+_h$ is the autocorrelation between $x_t$ and $x_{t+h}$ without the contribution of $ x_{t+1} ,x_{t+2} ,....,x_{t+h−1}$.The PACF is the sequence $ϕ_{h,h}$, _h = 1, 2,...,N – 1_.
#
# Partial autocorrelation plots (PACF), display correlation between a variable and its lags that is not explained by previous lags. PACF plots are useful when determining the order of the AR(p) model.

# %%
acf(residualbanana_add, main="ACF Random for Additive")
acf(residualbanana_mult, main="ACF Random for Multiplicative")
# Out:
# Plot with title "ACF Random for Additive"
# Plot with title "ACF Random for Multiplicative"

# %%
acf(residualgold_add, main="ACF Random for Additive")
acf(residualgold_mult, main="ACF Random for Multiplicative")
# Out:
# Plot with title "ACF Random for Additive"
# Plot with title "ACF Random for Multiplicative"

# %%
pacf(residualbanana_add, main="PACF Random for Additive ")
pacf(residualbanana_mult, main="PACF Random for Multiplicative")
# Out:
# Plot with title "PACF Random for Additive "
# Plot with title "PACF Random for Multiplicative"

# %%
pacf(residualgold_add, main="PACF Random for Additive")
pacf(residualgold_mult, main="PACF Random for Multiplicative")
# Out:
# Plot with title "PACF Random"

# %%
library(forecast)
# Out:
# Attaching package: 'forecast'
#
# The following object is masked _by_ '.GlobalEnv':
#
#     gold

# %%
auto.arima(residualbanana_add)
auto.arima(residualbanana_mult)
# Out:
# Series: residualbanana_add
# ARIMA(0,0,1)(0,0,1)[12] with non-zero mean
#
# Coefficients:
#          ma1     sma1    mean
#       0.3991  -0.0266  0.1869
# s.e.  0.0427   0.0471  4.1098
#
# sigma^2 estimated as 4016:  log likelihood=-2437.33
# AIC=4882.66   AICc=4882.75   BIC=4898.99
# Series: residualbanana_mult
# ARIMA(2,0,5) with non-zero mean
#
# Coefficients:
#          ar1      ar2      ma1     ma2      ma3      ma4     ma5    mean
#       1.2766  -0.5706  -1.0816  0.2364  -0.0362  -0.2239  0.1803  0.9992
# s.e.  0.1447   0.0679   0.1550  0.0875   0.0742   0.0881  0.0980  0.0014
#
# sigma^2 estimated as 0.01251:  log likelihood=341.24
# AIC=-664.48   AICc=-664.06   BIC=-627.74

# %%
arb_add<-auto.arima(residualbanana_add)
arb_mult<-auto.arima(residualbanana_mult)

# %%
plot(arb_add$residuals)
plot(arb_mult$residuals)
# Out:
# plot without title
# plot without title

# %%
var(arb_add$residuals)
var(arb_mult$residuals)
# Out:
# [1] 3997.186
# [1] 0.01230823

# %%
stdbanana_add<-(arb_add$residuals-mean(arb_add$residuals))/sqrt(var(arb_add$residuals))
stdbanana_mult<-(arb_mult$residuals-mean(arb_mult$residuals))/sqrt(var(arb_mult$residuals))

# %%
length(stdbanana_add)
length(stdbanana_mult)
# Out:
# [1] 438
# [1] 438

# %%
auto.arima(residualgold_add)
auto.arima(residualgold_mult)
# Out:
# Series: residualgold_add
# ARIMA(2,0,3)(0,0,1)[12] with zero mean
#
# Coefficients:
#          ar1      ar2      ma1     ma2     ma3     sma1
#       0.5466  -0.7681  -0.0888  0.6927  0.2567  -0.0663
# s.e.  0.0719   0.0869   0.0804  0.0700  0.0659   0.0423
#
# sigma^2 estimated as 789.7:  log likelihood=-2793.04
# AIC=5600.07   AICc=5600.27   BIC=5630.71
# Series: residualgold_mult
# ARIMA(2,0,1) with non-zero mean
#
# Coefficients:
#          ar1      ar2      ma1    mean
#       1.3591  -0.6195  -0.7996  0.9978
# s.e.  0.0475   0.0325   0.0536  0.0014
#
# sigma^2 estimated as 0.001956:  log likelihood=1000.92
# AIC=-1991.85   AICc=-1991.75   BIC=-1969.96

# %%
arg_add<-auto.arima(residualgold_add)
arg_mult<-auto.arima(residualgold_mult)

# %%
plot(arg_add$residuals)
plot(arg_mult$residuals)
# Out:
# plot without title
# plot without title

# %%
var(arg_add$residuals)
var(arg_mult$residuals)
# Out:
# [1] 782.9297
# [1] 0.001945685

# %%
stdgold_add<-(arg_add$residuals-mean(arg_add$residuals))/sqrt(var(arg_add$residuals))
stdgold_mult<-(arg_mult$residuals-mean(arg_mult$residuals))/sqrt(var(arg_mult$residuals))

# %%
length(stdgold_add)
length(stdgold_mult)
# Out:
# [1] 588
# [1] 588

# %% [markdown]
# # Kolmogorov-Smirnov Test

# %% [markdown]
# The Kolmogorov-Smirnov test (KS-test) determines whether the two datasets are significantly different. The KS-test makes no assumptions about the distribution of data. So it is technically undistorted and not parametric.
# In a typical experiment, the data collected in a control group are compared to the data collected in a different comparison group to see if the first case has a different outcome in the second. If the results for the comparison group are the same as the results in the control group, we will not give a result. How different should the results be? Statistics aims to assign numbers to test results; P values indicate whether the numbers are significantly different. If P is "small", reject the null hypothesis.
#
# Kolmogorov-Smirnov Test is used as hypothetical analysis for two different situations:
#
# 1. One Sample K-S test: The objective is to test whether sample data showing an assigned experimental probability distribution conforms to the probability distribution of a well-defined theoretical host with well-known distribution parameters. In this type of problem, the null hypothesis Ho is that the experimental distribution of the sample data comes from a well-defined anachronistic probability distribution.
#
# 2. Two Samples K-S test: The objective is to test whether two sample data series with two different experimental probability distributions given are from the same probability distribution of the same single theoretical host. If the zero hypothesis Ho is such a problem, then the experimental distributions of the two sample representations come from a single anchoring probability distribution.
#
# The hypotheses for the test are:
#
# **Null hypothesis ($H_0$):** The data comes from the specified distribution.
#
# **Alternate Hypothesis ($H_1$):** At least one value does not match the specified distribution.
#
# That is,
# $H_0$: P = $P_0$, $H_1$: P ≠ $P_0$
# Where P is the distribution of sample and $P_0$ is a specified distribution.
#
# The K-S test statistic measures the largest distance between the $F_{data}$(x) and the theoretical function $F_0(x)$, measured in a vertical direction. The test statistic is given by:
# $$ D = sup_x|F_0(x)-F_{data}(x)| $$
#
# Where:
#
# $F_0(x)$ = the cumulative distribution function of the hypothesized distribution
# $F_{data}(x)$ = the empirical distribution function of observed data
#
# _Advantages of K-S Test_
#
# 1. The test is exempt from distribution. It is not necessary to know the distribution of the data before running this test.
# 2. It is easy to calculate the D statistic used for the test.
# 3. There is no restriction on the size of the sample.
# 3. Ready tables are available.
#
# _There are also a few limitations for K-S Test:_
#
# The position, scale and shape parameters must be specified in order for the test to work. If these parameters are estimated from the data, it will invalidate the test.

# %%
ks.test(stdbanana_add, rnorm(500))
# Out:
# 	Two-sample Kolmogorov-Smirnov test
#
# data:  stdbanana_add and rnorm(500)
# D = 0.10038, p-value = 0.01809
# alternative hypothesis: two-sided

# %%
ks.test(stdbanana_mult, rnorm(500))
# Out:
# 	Two-sample Kolmogorov-Smirnov test
#
# data:  stdbanana_mult and rnorm(500)
# D = 0.052932, p-value = 0.5299
# alternative hypothesis: two-sided

# %%
ks.test(stdgold_add, rnorm(500))
# Out:
# 	Two-sample Kolmogorov-Smirnov test
#
# data:  stdgold_add and rnorm(500)
# D = 0.16933, p-value = 3.724e-07
# alternative hypothesis: two-sided

# %%
ks.test(stdgold_mult, rnorm(500))
# Out:
# 	Two-sample Kolmogorov-Smirnov test
#
# data:  stdgold_mult and rnorm(500)
# D = 0.076027, p-value = 0.08797
# alternative hypothesis: two-sided

# %% [markdown]
# _In this study, we intended to analyze the time series using the R programming language.At first, we examined what is the commodity market, how it works, what are the features. Then, we chose our data sets to work on , which belong to banana and gold, from Quandl and we linked these data sets to the R programming library. In the other phase, we used ts () function to convert these data sets into time series type from data frame type that we can analyze. However, since we can not be sure of looking at the diagrams only if these time series are additive or multiplicative, we can make sure that we have distributed all of our codes on both types so that we can proceed with the normality test at the end of our study. We use decompose(), which is a decomposition function for these time series, to distinguish them between trend, seasonal, cyclical and irregular components. We tried to observe the differences between these two functions by applying the stl () function, which is another decomposition function, but we see that these two functions give the same result on our data sets. In this case, we decided to continue to work with the results we obtained from decompose (), which is more appropriate to observe the application and its components. So we have implemented ARIMA to remove any information can affect the results in the remaining data. We used the auto.arima () function to apply ARIMA in R. Finally, after applying ARIMA, we took the residuals of the residual data and checked the residual is white noise or not by performing the Kolmogorov-Smirnov normality test, and we concluded that both data sets were multiplicative time series and the residuals are white noise._
