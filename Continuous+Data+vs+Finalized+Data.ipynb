# %%
library(Quandl)
# Out:
# Loading required package: xts
# Loading required package: zoo
#
# Attaching package: 'zoo'
#
# The following objects are masked from 'package:base':
#
#     as.Date, as.Date.numeric

# %%
Quandl("ODA/PBANSOP_USD", api_key="2Tn6xx-X8y8ywzbtYPWZ")
# Out:
#     Date       Value
# 1   2017-06-30 1098.07
# 2   2017-05-31 1083.05
# 3   2017-04-30 1063.54
# 4   2017-03-31 1075.25
# 5   2017-02-28 1040.10
# 6   2017-01-31  974.03
# 7   2016-12-31  959.94
# 8   2016-11-30  959.94
# 9   2016-10-31  976.39
# 10  2016-09-30 1013.31
# 11  2016-08-31 1051.53
# 12  2016-07-31 1004.67
# 13  2016-06-30  993.22
# 14  2016-05-31  987.57
# 15  2016-04-30  998.09
# 16  2016-03-31 1020.90
# 17  2016-02-29 1052.35
# 18  2016-01-31 1011.25
# 19  2015-12-31  932.32
# 20  2015-11-30  932.32
# 21  2015-10-31  933.58
# 22  2015-09-30  951.78
# 23  2015-08-31  956.66
# 24  2015-07-31  938.33
# 25  2015-06-30  929.18
# 26  2015-05-31  946.79
# 27  2015-04-30 1059.14
# 28  2015-03-31 1045.96
# 29  2015-02-28  966.85
# 30  2015-01-31  911.60
# ... ...        ...
# 421 1982-06-30 399.76
# 422 1982-05-31 438.35
# 423 1982-04-30 476.40
# 424 1982-03-31 421.81
# 425 1982-02-28 383.21
# 426 1982-01-31 425.12
# 427 1981-12-31 416.30
# 428 1981-11-30 395.90
# ...

# %%
x=Quandl("ODA/PBANSOP_USD", api_key="2Tn6xx-X8y8ywzbtYPWZ")

# %%
Quandl("CHRIS/ICE_KC1", api_key="2Tn6xx-X8y8ywzbtYPWZ")
# Out:
#       Date       Open   High   Low    Settle Change Wave   Volume
# 1     2017-11-10 126.05 128.35 125.50 127.55  1.15  127.17 34377
# 2     2017-11-09 125.55 127.40 125.00 126.40  0.65  126.54 31153
# 3     2017-11-08 125.05 125.90 124.20 125.75  1.05  125.16 30256
# 4     2017-11-07 125.50 125.80 123.10 124.70 -0.85  124.52 29168
# 5     2017-11-06 123.95 126.40 122.25 125.55  1.60  124.56 18625
# 6     2017-11-03 127.15 127.40 123.25 123.95 -2.45  125.00 25591
# 7     2017-11-02 123.35 127.60 122.55 126.40  3.45  125.23 33634
# 8     2017-11-01 124.70 126.20 121.20 122.95 -2.15  122.71 34714
# 9     2017-10-31 125.10 125.70 124.15 125.10 -0.80  124.83 22004
# 10    2017-10-30 127.00 127.75 125.05 125.90 -0.70  126.34 12843
# 11    2017-10-27 124.00 127.50 123.70 126.60  2.05  126.16 21413
# 12    2017-10-26 124.40 124.90 123.00 124.55  0.45  123.94 18914
# 13    2017-10-25 123.30 125.30 123.10 124.10  0.90  124.16 13174
# ...

# %%
y=Quandl("CHRIS/ICE_KC1", api_key="2Tn6xx-X8y8ywzbtYPWZ")

# %%
summary(x)
# Out:
#       Date                Value
#  Min.   :1980-01-31   Min.   : 250.5
#  1st Qu.:1989-06-07   1st Qu.: 407.5
#  Median :1998-10-15   Median : 511.4
#  Mean   :1998-10-15   Mean   : 590.4
#  3rd Qu.:2008-02-21   3rd Qu.: 805.2
#  Max.   :2017-06-30   Max.   :1151.4

# %%
summary(y)
# Out:
#       Date                 Open             High             Low
#  Min.   :1973-08-20   Min.   : 41.50   Min.   : 42.00   Min.   : 41.50
#  1st Qu.:1984-08-01   1st Qu.: 90.03   1st Qu.: 91.25   1st Qu.: 89.01
#  Median :1995-07-05   Median :125.00   Median :126.10   Median :123.75
#  Mean   :1995-08-31   Mean   :126.81   Mean   :128.40   Mean   :125.35
#  3rd Qu.:2006-09-25   3rd Qu.:149.00   3rd Qu.:150.50   3rd Qu.:147.50
#  Max.   :2017-11-10   Max.   :336.00   Max.   :337.50   Max.   :335.00
#                       NA's   :33       NA's   :33       NA's   :33
#      Settle           Change             Wave           Volume
#  Min.   : 41.50   Min.   :-35.350   Min.   :112.9   Min.   :    0.0
#  1st Qu.: 90.35   1st Qu.: -1.400   1st Qu.:126.4   1st Qu.:  102.8
#  Median :125.05   Median :  0.000   Median :137.1   Median :  773.0
#  Mean   :126.86   Mean   :  0.002   Mean   :136.5   Mean   : 3921.9
#  3rd Qu.:148.87   3rd Qu.:  1.350   3rd Qu.:144.2   3rd Qu.: 5781.8
# ...

# %%
x=Quandl("ODA/PBANSOP_USD", "type=ts")
# Out:
# Error in match.arg(type): 'arg' should be one of "raw", "ts", "zoo", "xts", "timeSeries"
# Traceback:
#
# 1. Quandl("ODA/PBANSOP_USD", "type=ts")
# 2. match.arg(type)
# 3. stop(gettextf("'arg' should be one of %s", paste(dQuote(choices),
#  .     collapse = ", ")), domain = NA)

# %%
x=Quandl("ODA/PBANSOP_USD", type="ts")

# %%
plot(x)
# Out:
# plot without title

# %%
y=Quandl("CHRIS/ICE_KC1",type="ts")
# Out:
# Warning message in Quandl("CHRIS/ICE_KC1", type = "ts"):
# "Type 'ts' does not support frequency 365. Returning zoo."

# %%
plot(y)
# Out:
# Plot with title "y"

# %%
boxplot(y)
# Out:
# Error in order(x, ..., na.last = na.last, decreasing = decreasing): 1 argümanı bir vektör değil
# Traceback:
#
# 1. boxplot(y)
# 2. boxplot.default(y)
# 3. do.call("bxp", c(list(z, notch = notch, width = width, varwidth = varwidth,
#  .     log = log, border = border, pars = pars, outline = outline,
#  .     horizontal = horizontal, add = add, at = at), args[namedargs]))
# 4. bxp(structure(list(stats = structure(c(-35.35, 55.525, 123.65,
#  . 205.375, 430), .Dim = c(5L, 1L), class = structure("zoo", .Names = "1")),
#  .     n = 84707, conf = structure(c(122.836506319082, 124.463493680918
#  .     ), .Dim = c(2L, 1L)), out = c(507, 501, 465, 557, 639, 599,
#  .     568, 522, 465, 593, 457, 524, 621, 437, 556, 432, 466, 449,
#  .     440, 492, 437, 644, 448, 511, 596, 594, 465, 625, 455, 842,
#  .     749, 995, 771, 710, 632, 646, 678, 1151, 452, 781, 478, 470,
#  .     567, 569, 523, 672, 560, 791, 767, 1063, 753, 653, 669, 542,
# ...

# %%
y = Quandl("CHRIS/ICE_KC1", start_date="2001-12-31", end_date="2005-12-31")

# %%
y = Quandl("CHRIS/ICE_KC1", start_date="2001-12-31", end_date="2005-12-31", type="ts")
# Out:
# Warning message in Quandl("CHRIS/ICE_KC1", start_date = "2001-12-31", end_date = "2005-12-31", :
# "Type 'ts' does not support frequency 365. Returning zoo."

# %%
plot(y)
# Out:
# Warning message in min(x):
# "min için eksik olmayan argüman yok; Inf döndürülüyor"Warning message in max(x):
# "max için eksik olmayan argüman yok; -Inf döndürülüyor"Warning message in min(x):
# "min için eksik olmayan argüman yok; Inf döndürülüyor"Warning message in max(x):
# "max için eksik olmayan argüman yok; -Inf döndürülüyor"
# Error in plot.window(...): sonlu 'ylim' değerleri gerekli
# Traceback:
#
# 1. plot(y)
# 2. plot.zoo(y)
# 3. do.call("plot", args)
# 4. plot(structure(c(11689, 11690, 11691, 11694, 11695, 11696, 11697,
#  . 11698, 11701, 11702, 11703, 11704, 11705, 11709, 11710, 11711,
#  . 11712, 11715, 11716, 11717, 11718, 11719, 11722, 11723, 11724,
#  . 11725, 11726, 11729, 11730, 11731, 11732, 11733, 11737, 11738,
#  . 11739, 11740, 11743, 11744, 11745, 11746, 11747, 11750, 11751,
#  . 11752, 11753, 11754, 11757, 11758, 11759, 11760, 11761, 11764,
#  . 11766, 11767, 11768, 11771, 11772, 11773, 11774, 11778, 11779,
# ...
